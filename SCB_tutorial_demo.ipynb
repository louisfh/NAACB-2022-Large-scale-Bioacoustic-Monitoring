# %% [markdown]
# <a href="https://colab.research.google.com/github/louisfh/notebooks/blob/main/SCB_tutorial_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SCB workshop tutorial OpenSoundscape
# The first part of the tutorial involves installing OpenSoundscape on the machine running google colab. Don't worry about the messy error messages below - this is due to Google Colab already having a set of packages installed, and us asking it to install a new set! After running the first cell below, you will need to click 'restart runtime'.

# %%
# !pip install -q opensoundscape

# %% [markdown]
# ## Lets load in the audio you just recorded on an audio moth
# First we need to upload the audio so Google Colab can access it. Use the choose files button below to find the audiomoth recording.

# %%
from google.colab import files

recording = files.upload()
filename = "YOUR_FILENAME" #ENTER YOUR FILENAME HERE
filename = "playback1_f1_1m.wav"
# Out:
#      <input type="file" id="files-8bb1f7b0-69e1-4b85-bdbf-e32363b76c0e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8bb1f7b0-69e1-4b85-bdbf-e32363b76c0e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving playback1_f1_1m.wav to playback1_f1_1m (2).wav

# %% [markdown]
# ## Now we're going to 'import' OpenSoundscape
# To make your code a bit easier to read, we also want to import specific functions and classes from OpenSoundscape. e.g. instead of having to type `opensoundscape.audio.spectogram.Spectrogram.from_file` every time we want to make a spectrogram from an audio file, if we first declare `from opensoundscape.spectrogram import Spectrogram` we can simply write `Spectrogram.from_audio` each time we want to make a spectrogram.

# %%
import opensoundscape
from opensoundscape.audio import Audio
from opensoundscape.spectrogram import Spectrogram

# %%
audio = Audio.from_file("playback1_f1_1m.wav")
s = Spectrogram.from_audio(audio)
s.plot()

# %% [markdown]
# ### Lets download a model we trained earlier!
# To save some time we trained a model already.

# %%
# !wget https://pitt.box.com/shared/static/0t39v5ytsuq4loo6tcnvl6d5e5fjnids.model
# Out:
# --2022-07-12 03:31:50--  https://pitt.box.com/shared/static/0t39v5ytsuq4loo6tcnvl6d5e5fjnids.model
# Resolving pitt.box.com (pitt.box.com)... 107.152.26.197
# Connecting to pitt.box.com (pitt.box.com)|107.152.26.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/0t39v5ytsuq4loo6tcnvl6d5e5fjnids.model [following]
# --2022-07-12 03:31:51--  https://pitt.box.com/public/static/0t39v5ytsuq4loo6tcnvl6d5e5fjnids.model
# Reusing existing connection to pitt.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://pitt.app.box.com/public/static/0t39v5ytsuq4loo6tcnvl6d5e5fjnids.model [following]
# --2022-07-12 03:31:51--  https://pitt.app.box.com/public/static/0t39v5ytsuq4loo6tcnvl6d5e5fjnids.model
# Resolving pitt.app.box.com (pitt.app.box.com)... 107.152.26.201
# Connecting to pitt.app.box.com (pitt.app.box.com)|107.152.26.201|:443... connected.
# ...

# %%
from opensoundscape.torch.models.cnn import load_model
model = load_model("0t39v5ytsuq4loo6tcnvl6d5e5fjnids.model")

# %%
preds = model.predict([filename])
# Out:
# []
